# %%
import pandas as pd
df=pd.read_csv("titanic-passengers.csv", sep=";")
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df["Age"].fillna(df["Age"].ffill(), inplace=True)
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %% [markdown]
# ## Replacing

# %%
number_of_elements=len(df["Cabin"])
print("number_of_elements", number_of_elements)
# Out:
# number_of_elements 891

# %%
print(df["Cabin"].value_counts())
# Out:
# G6             4
# B96 B98        4
# C23 C25 C27    4
# F33            3
# D              3
#               ..
# C91            1
# D45            1
# F G63          1
# A34            1
# E63            1
# Name: Cabin, Length: 147, dtype: int64

# %%
df["Cabin"].fillna("G6", inplace=True)

# %%
df.tail()
# Out:
#      PassengerId Survived  Pclass  \
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male  30.0      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 886      0  237736  30.0708    G6        C
# 887      0    2669   7.2292    G6        C
# 888      0  315084   8.6625    G6        S
# 889      0  349215   7.8958    G6        S
# 890      0  250655  26.0000    G6        S

# %%
print(df["Cabin"].value_counts())
# Out:
# G6             691
# C23 C25 C27      4
# B96 B98          4
# D                3
# C22 C26          3
#               ...
# D45              1
# F G63            1
# A34              1
# C85              1
# E63              1
# Name: Cabin, Length: 147, dtype: int64

# %%
CLKup={"Survived":{"Yes":1,"No":0}}
grid = sns.FacetGrid(df, col="Survived", height=2.2, aspect=1.6)
grid.map(sns.barplot, "Sex", "Age", alpha=0.5, ci=None)
grid.add_legend()
# Out:
# C:\Users\aboud\GMC\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
CLKup={"Survived":{"Yes":1,"No":0}}
grid = sns.FacetGrid(df, row='Embarked', col='Survived', height=2.2, aspect=1.6)
grid.map(sns.barplot, 'Sex', 'Fare', alpha=0.5, ci=None)
grid.add_legend()
# Out:
# C:\Users\aboud\GMC\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# ## Analyse and describe the function

# %%
df.corr()
# Out:
#              PassengerId    Pclass       Age     SibSp     Parch      Fare
# PassengerId     1.000000 -0.035144  0.025221 -0.057527 -0.001652  0.012658
# Pclass         -0.035144  1.000000 -0.302842  0.083081  0.018443 -0.549500
# Age             0.025221 -0.302842  1.000000 -0.234012 -0.169161  0.089791
# SibSp          -0.057527  0.083081 -0.234012  1.000000  0.414838  0.159651
# Parch          -0.001652  0.018443 -0.169161  0.414838  1.000000  0.216225
# Fare            0.012658 -0.549500  0.089791  0.159651  0.216225  1.000000

# %%
def plot_correlation_map( df ):
    corr = df.corr()
    s , ax = plt.subplots( figsize =( 12 , 10 ) )
    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
    s = sns.heatmap(
        corr, 
        cmap = cmap,
        square=True, 
        cbar_kws={ 'shrink' : .9 }, 
        ax=ax, 
        annot = True, 
        annot_kws = { 'fontsize' : 12 }
        )

# %%
plot_correlation_map( df )

# %% [markdown]
# #En gros, pour savoir si on a une forte liaison (relation) entre les inputs, on utilise le " corr()". corr() est utilisé pour trouver la corrélation entre chaque 2 données de toutes les colonnes (numeriques) dans la dataframe. Pour simplifier la lecture de ces nombres et le choix des inputs qui ont une forte relation (1 et -1), on a recourt à la heatmap et à la palette des couleurs.

# %%
df.replace(CLKup, inplace=True)
df[["Pclass","Survived"]].groupby(["Pclass"],as_index=True).mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass                                         Name  \
# 0          343         0       2                   Collander, Mr. Erik Gustaf
# 1           76         0       3                      Moen, Mr. Sigurd Hansen
# 2          641         0       3                       Jensen, Mr. Hans Peder
# 3          568         0       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672         0       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000     G6        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542     G6        S
# 3  female  29.0      0      4      349909  21.0750     G6        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
del df["Ticket"]
df.head()
# Out:
#    PassengerId  Survived  Pclass                                         Name  \
# 0          343         0       2                   Collander, Mr. Erik Gustaf
# 1           76         0       3                      Moen, Mr. Sigurd Hansen
# 2          641         0       3                       Jensen, Mr. Hans Peder
# 3          568         0       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672         0       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch     Fare  Cabin Embarked
# 0    male  28.0      0      0  13.0000     G6        S
# 1    male  25.0      0      0   7.6500  F G73        S
# 2    male  20.0      0      0   7.8542     G6        S
# 3  female  29.0      0      4  21.0750     G6        S
# 4    male  31.0      1      0  52.0000    B71        S

# %%
split1
# Out:
#                                                   Redo         IDK  \
# 0                                      Mr. Erik Gustaf   Collander
# 1                                    Mr. Sigurd Hansen        Moen
# 2                                       Mr. Hans Peder      Jensen
# 3                   Mrs. Nils (Alma Cornelia Berglund)     Palsson
# 4                                         Mr. Thornton    Davidson
# ..                                                 ...         ...
# 886                        Mrs. Nicholas (Adele Achem)      Nasser
# 887                                          Mr. Orsen  Sirayanian
# 888                                       Miss. Marija       Cacic
# 889                            Mr. Pastcho ("Pentcho")     Petroff
# 890  Miss. Kate Florence ("Mrs Kate Louise Phillips...    Phillips
#
#                                                 Title1
# 0                                      Mr. Erik Gustaf
# ...

# %%
Redo=split1[["Redo"]]

# %%
Redo
# Out:
#                                                   Redo
# 0                                      Mr. Erik Gustaf
# 1                                    Mr. Sigurd Hansen
# 2                                       Mr. Hans Peder
# 3                   Mrs. Nils (Alma Cornelia Berglund)
# 4                                         Mr. Thornton
# ..                                                 ...
# 886                        Mrs. Nicholas (Adele Achem)
# 887                                          Mr. Orsen
# 888                                       Miss. Marija
# 889                            Mr. Pastcho ("Pentcho")
# 890  Miss. Kate Florence ("Mrs Kate Louise Phillips...
#
# [891 rows x 1 columns]

# %%
T=Redo['Redo'].str.split('. ', expand=True)
T
# Out:
#        0         1            2        3          4      5        6   \
# 0      Mr       Eri       Gustaf     None       None   None     None
# 1      Mr     Sigur       Hansen     None       None   None     None
# 2      Mr       Han        Peder     None       None   None     None
# 3     Mrs       Nil         (Alm  Corneli  Berglund)   None     None
# 4      Mr  Thornton         None     None       None   None     None
# ..    ...       ...          ...      ...        ...    ...      ...
# 886   Mrs   Nichola        (Adel   Achem)       None   None     None
# 887    Mr     Orsen         None     None       None   None     None
# 888  Miss    Marija         None     None       None   None     None
# 889    Mr    Pastch  ("Pentcho")     None       None   None     None
# 890  Miss       Kat      Florenc     ("Mr        Kat  Louis  Phillip
#
#              7     8     9     10
# 0          None  None  None  None
# 1          None  None  None  None
# ...

# %%
Title=T[0]
Title
# Out:
# 0        Mr
# 1        Mr
# 2        Mr
# 3       Mrs
# 4        Mr
#        ...
# 886     Mrs
# 887      Mr
# 888    Miss
# 889      Mr
# 890    Miss
# Name: 0, Length: 891, dtype: object

# %%
del T

# %%
df.insert(loc=4, column="Title", value=Title)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [312], in <cell line: 1>()
# ----> 1 df.insert(loc=4, column="Title", value=Title)
#
# File ~\GMC\lib\site-packages\pandas\core\frame.py:4440, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4434     raise ValueError(
#    4435         "Cannot specify 'allow_duplicates=True' when "
#    4436         "'self.flags.allows_duplicate_labels' is False."
#    4437     )
#    4438 if not allow_duplicates and column in self.columns:
#    4439     # Should this be a different kind of error??
# -> 4440     raise ValueError(f"cannot insert {column}, already exists")
#    4441 if not isinstance(loc, int):
#    4442     raise TypeError("loc must be int")
#
# ValueError: cannot insert Title, already exists

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name Title     Sex   Age  \
# 0                           Collander, Mr. Erik Gustaf    Mr    male  28.0
# 1                              Moen, Mr. Sigurd Hansen    Mr    male  25.0
# 2                               Jensen, Mr. Hans Peder    Mr    male  20.0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)   Mrs  female  29.0
# 4                               Davidson, Mr. Thornton    Mr    male  31.0
# ..                                                 ...   ...     ...   ...
# ...

# %%
CLKup={"Sex":{"female":1,"male":0}}
grid = sns.FacetGrid(df, col="Sex", height=2.2, aspect=1.6)
grid.map(sns.barplot, "Title", "Age", alpha=0.5, ci=None)
grid.add_legend()
# Out:
# C:\Users\aboud\GMC\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
Title_Dictionary = {"Capt":       "Officer",
                    "Col":        "Officer",
                    "Major":      "Officer",
                      "Dr":         "Officer",
                    "Rev":        "Officer",
                    "Jonkheer":   "Royalty",
                    "Don":        "Royalty",
                    "Sir" :       "Royalty",
                   "Lady" :      "Royalty",
                  "the Countess": "Royalty",
                    "Dona":       "Royalty",
                    "Mme":        "Miss",
                    "Mlle":       "Miss",
                    "Miss" :      "Miss",
                    "Ms":         "Mrs",
                    "Mr" :        "Mrs",
                    "Mrs" :       "Mrs",
                    "Master" :    "Master"
                    }
Title_Dictionary
# Out:
# {'Capt': 'Officer',
#  'Col': 'Officer',
#  'Major': 'Officer',
#  'Dr': 'Officer',
#  'Rev': 'Officer',
#  'Jonkheer': 'Royalty',
#  'Don': 'Royalty',
#  'Sir': 'Royalty',
#  'Lady': 'Royalty',
#  'the Countess': 'Royalty',
#  'Dona': 'Royalty',
#  'Mme': 'Miss',
#  'Mlle': 'Miss',
#  'Miss': 'Miss',
#  'Ms': 'Mrs',
#  'Mr': 'Mrs',
#  'Mrs': 'Mrs',
#  'Master': 'Master'}

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name Title     Sex   Age  \
# 0                           Collander, Mr. Erik Gustaf    Mr    male  28.0
# 1                              Moen, Mr. Sigurd Hansen    Mr    male  25.0
# 2                               Jensen, Mr. Hans Peder    Mr    male  20.0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)   Mrs  female  29.0
# 4                               Davidson, Mr. Thornton    Mr    male  31.0
# ..                                                 ...   ...     ...   ...
# ...

# %%
df['Title']=df['Title'].map(Title_Dictionary) #on remplace les plsr titres par les nouveaux

# %%
df['Title']
# Out:
# 0       Mrs
# 1       Mrs
# 2       Mrs
# 3       Mrs
# 4       Mrs
#        ...
# 886     Mrs
# 887     Mrs
# 888    Miss
# 889     Mrs
# 890    Miss
# Name: Title, Length: 891, dtype: object

# %%
df['Title'].value_counts()
# Out:
# Mrs        643
# Miss       185
# Master      40
# Officer     18
# Royalty      4
# Name: Title, dtype: int64

# %%
FamilySize=df[["Parch","SibSp"]].groupby(["Parch"],as_index=True).mean()
FamilySize
# Out:
#           SibSp
# Parch
# 0      0.237463
# 1      1.084746
# 2      2.062500
# 3      1.000000
# 4      0.750000
# 5      0.600000
# 6      1.000000

# %% [markdown]
# I actually knew how to make in practice what I've learnt... I also learnt new way to do some things like the drop, the loc and the insert, etc. I descovred actually the to make the heatmap and remembred some functions from the courses.
